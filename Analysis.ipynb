# %% [markdown]
# <a href="https://colab.research.google.com/github/leosammallahti/AnalysisCoLab/blob/main/Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import warnings
warnings.filterwarnings('ignore')

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Load the enriched RCT dataset
data_path = '/content/drive/MyDrive/AEA_RCT_Parsed/structured_studies_full_v2.csv'
df = pd.read_csv(data_path, low_memory=False)

# Display basic info
print(f"Dataset loaded: {len(df)} studies")
print(f"Columns available: {df.columns.tolist()[:10]}... [{len(df.columns)} total columns]")

# Filter out studies with inadequate abstracts (as noted in your pipeline)
df['abstract_length'] = df['abstract'].fillna('').str.len()
df_clean = df[df['abstract_length'] >= 100].copy()
print(f"\nAfter filtering short/missing abstracts: {len(df_clean)} studies remain")
print(f"Removed {len(df) - len(df_clean)} studies with inadequate abstracts")

# Check the AI-generated fields we'll analyze
ai_fields = ['tldr', 'intervention_type', 'outcome_extracted', 'population_extracted', 'country_extracted']
print("\n=== AI-Generated Fields Coverage ===")
for field in ai_fields:
    coverage = df_clean[field].notna().sum() / len(df_clean) * 100
    print(f"{field}: {coverage:.1f}% complete")

print("\nDataset ready for Solution Families clustering!")
# Out:
# Mounted at /content/drive
# Dataset loaded: 2289 studies
# Columns available: ['rct_id', 'title', 'final_has_findings', 'final_findings_snippet', 'final_findings_source_type', 'country', 'start_date', 'end_date', 'primary_investigator_name', 'origin_url']... [122 total columns]
#
# After filtering short/missing abstracts: 2105 studies remain
# Removed 184 studies with inadequate abstracts
#
# === AI-Generated Fields Coverage ===
# tldr: 100.0% complete
# intervention_type: 99.8% complete
# outcome_extracted: 99.8% complete
# population_extracted: 99.5% complete
# country_extracted: 68.3% complete
#
# Dataset ready for Solution Families clustering!

# %%
# Prepare combined text for clustering based on intervention characteristics
print("=== Preparing Text for Solution Families Clustering ===\n")

# Combine relevant AI-generated fields to capture intervention essence
df_clean['intervention_essence'] = (
    df_clean['intervention_type'].fillna('') + ' | ' +
    df_clean['tldr'].fillna('') + ' | ' +
    df_clean['outcome_extracted'].fillna('') + ' | ' +
    df_clean['population_extracted'].fillna('')
)

# Remove empty rows
df_analysis = df_clean[df_clean['intervention_essence'].str.len() > 50].copy()
print(f"Studies with sufficient text for analysis: {len(df_analysis)}")

# Create TF-IDF vectors for clustering
print("\nCreating TF-IDF vectors...")
vectorizer = TfidfVectorizer(
    max_features=200,
    stop_words='english',
    min_df=3,
    max_df=0.8,
    ngram_range=(1, 2)
)

intervention_vectors = vectorizer.fit_transform(df_analysis['intervention_essence'])
print(f"Vector shape: {intervention_vectors.shape}")

# Get top features for understanding what drives the clustering
feature_names = vectorizer.get_feature_names_out()
print(f"\nTop 20 most distinctive terms across all interventions:")
print(list(feature_names[:20]))

print("\n✓ Text data prepared for clustering!")
# Out:
# === Preparing Text for Solution Families Clustering ===
#
# Studies with sufficient text for analysis: 2104
#
# Creating TF-IDF vectors...
# Vector shape: (2104, 200)
#
# Top 20 most distinctive terms across all interventions:
# ['academic', 'adoption', 'adult', 'adults', 'agricultural', 'attitudes', 'based', 'behavior', 'behavioral', 'belief', 'beliefs', 'benefits', 'bias', 'boost', 'boosts', 'business', 'cash', 'change', 'child', 'children']
#
# ✓ Text data prepared for clustering!

# %%
# Find optimal number of clusters using elbow method
from sklearn.metrics import silhouette_score

print("=== Finding Optimal Number of Solution Families ===\n")

# Test different numbers of clusters
inertias = []
silhouette_scores = []
K_range = range(5, 16)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(intervention_vectors)
    inertias.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(intervention_vectors, kmeans.labels_))
    print(f"k={k}: Silhouette Score = {silhouette_scores[-1]:.3f}")

# Find best k based on silhouette score
best_k = K_range[np.argmax(silhouette_scores)]
print(f"\n✓ Optimal number of Solution Families: {best_k}")

# Perform final clustering with optimal k
print(f"\n=== Creating {best_k} Solution Families ===")
final_kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=20)
df_analysis['solution_family'] = final_kmeans.fit_predict(intervention_vectors)

# Show distribution
family_counts = df_analysis['solution_family'].value_counts().sort_index()
print("\nCluster sizes:")
for cluster_id, count in family_counts.items():
    print(f"  Family {cluster_id}: {count} studies ({count/len(df_analysis)*100:.1f}%)")

print("\n✓ Solution Families created! Ready for AI naming and analysis.")
# Out:
# === Finding Optimal Number of Solution Families ===
#
# k=5: Silhouette Score = 0.034
# k=6: Silhouette Score = 0.038
# k=7: Silhouette Score = 0.039
# k=8: Silhouette Score = 0.042
# k=9: Silhouette Score = 0.044
# k=10: Silhouette Score = 0.047
# k=11: Silhouette Score = 0.047
# k=12: Silhouette Score = 0.045
# k=13: Silhouette Score = 0.048
# k=14: Silhouette Score = 0.050
# k=15: Silhouette Score = 0.054
#
# ✓ Optimal number of Solution Families: 15
#
# === Creating 15 Solution Families ===
#
# Cluster sizes:
#   Family 0: 128 studies (6.1%)
#   Family 1: 252 studies (12.0%)
#   Family 2: 122 studies (5.8%)
#   Family 3: 63 studies (3.0%)
#   Family 4: 414 studies (19.7%)
#   Family 5: 42 studies (2.0%)
#   Family 6: 97 studies (4.6%)
#   Family 7: 143 studies (6.8%)
#   Family 8: 144 studies (6.8%)
#   Family 9: 85 studies (4.0%)
#   Family 10: 141 studies (6.7%)
#   Family 11: 47 studies (2.2%)
#   Family 12: 102 studies (4.8%)
#   Family 13: 194 studies (9.2%)
#   Family 14: 130 studies (6.2%)
#
# ✓ Solution Families created! Ready for AI naming and analysis.

# %%
from together import Together
from google.colab import userdata

# Initialize Together AI client
api_key = userdata.get('TOGETHER_API_KEY')
client = Together(api_key=api_key)

print("=== Analyzing Solution Families with Kimi-K2-Instruct ===\n")

# Function to get top terms for each cluster
def get_cluster_top_terms(cluster_id, n_terms=15):
    cluster_docs = df_analysis[df_analysis['solution_family'] == cluster_id]['intervention_essence']

    # Create TF-IDF for this cluster
    cluster_vectorizer = TfidfVectorizer(max_features=n_terms, stop_words='english', ngram_range=(1,2))
    try:
        cluster_vectorizer.fit(cluster_docs)
        return list(cluster_vectorizer.get_feature_names_out())
    except:
        return []

# Function to get representative studies
def get_cluster_samples(cluster_id, n_samples=3):
    cluster_df = df_analysis[df_analysis['solution_family'] == cluster_id]
    samples = cluster_df.sample(min(n_samples, len(cluster_df)), random_state=42)
    sample_list = []
    for _, row in samples.iterrows():
        sample_list.append({
            'title': row['title'],
            'intervention': row['intervention_type'],
            'summary': row['tldr'][:200]  # Truncate for brevity
        })
    return sample_list

# Analyze first 3 families as a test
solution_families = {}

for cluster_id in range(3):  # Start with first 3 to test
    print(f"\n--- Analyzing Solution Family {cluster_id} ---")

    # Get cluster characteristics
    cluster_size = len(df_analysis[df_analysis['solution_family'] == cluster_id])
    top_terms = get_cluster_top_terms(cluster_id)
    samples = get_cluster_samples(cluster_id)

    print(f"Size: {cluster_size} studies")
    print(f"Key terms: {', '.join(top_terms[:8])}")

    # Create prompt for AI
    prompt = f"""Analyze this cluster of development economics interventions and provide:
1. A short, catchy name (2-4 words) that captures the essence
2. A one-sentence description of the theory of change
3. Key mechanism: how these interventions work

Cluster characteristics:
- Size: {cluster_size} studies
- Top terms: {', '.join(top_terms)}
- Sample studies:
{chr(10).join([f"  • {s['title']}: {s['intervention']}" for s in samples[:2]])}

Respond in this exact format:
NAME: [name]
DESCRIPTION: [one sentence]
MECHANISM: [one sentence how it works]"""

    # Get AI response
    try:
        response = client.chat.completions.create(
            model="moonshotai/Kimi-K2-Instruct",
            messages=[{"role": "user", "content": prompt}],
            temperature=0.6,
            max_tokens=200
        )

        analysis = response.choices[0].message.content
        print(f"\n{analysis}")

        solution_families[cluster_id] = {
            'size': cluster_size,
            'top_terms': top_terms[:8],
            'analysis': analysis
        }

    except Exception as e:
        print(f"Error analyzing cluster {cluster_id}: {e}")

print("\n✓ Initial analysis complete! Ready to analyze remaining families.")
# Out:
# === Analyzing Solution Families with Kimi-K2-Instruct ===
#
#
# --- Analyzing Solution Family 0 ---
# Size: 128 studies
# Key terms: business, financial, firm, firms, management, performance, practices, productivity
#
# NAME: Productivity Bootcamps
# DESCRIPTION: Coach micro-entrepreneurs and their workers in modern management, finance, and peer-driven motivation so that better practices lift firm performance.
# MECHANISM: Intensive group training plus follow-up peer interaction transmits codified business know-how and social accountability, which owners and workers adopt, raising productivity and profits.
#
# --- Analyzing Solution Family 1 ---
# Size: 252 studies
# Key terms: academic, college, education, educational, high, learning, outcomes, performance
#
# NAME: Elite Teacher Pipeline
# DESCRIPTION: Recruit and fast-track high-achieving graduates into underserved classrooms to raise student learning outcomes.
# MECHANISM: Select top college grads, give them short, intensive training plus ongoing coaching, and place them as full-time teachers where they deliver higher-quality instruction that boosts test scores.
#
# --- Analyzing Solution Family 2 ---
# Size: 122 studies
# Key terms: discrimination, employment, individuals, job, job seekers, labor, labor market, market
#
# NAME: Bias-Busting Hiring
# DESCRIPTION: Reduce labor-market discrimination by experimentally exposing and then correcting biased recruitment practices.
# MECHANISM: Randomized audits and correspondence tests reveal discriminatory employer behavior, then targeted interventions (blind résumés, structured interviews, or feedback) shift hiring outcomes toward marginalized groups.
#
# ✓ Initial analysis complete! Ready to analyze remaining families.

# %%
# Install Together AI package
# !pip install together -q

print("✓ Together AI package installed successfully")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 5.5 MB/s eta 0:00:00
# ✓ Together AI package installed successfully

# %%
print("=== Examining Actual Cluster Composition ===\n")

# Let's look at Family 1 (the 252-study cluster) in detail
cluster_id = 1
cluster_df = df_analysis[df_analysis['solution_family'] == cluster_id]

print(f"SOLUTION FAMILY {cluster_id}: {len(cluster_df)} studies\n")

# Analyze intervention types
print("Top 10 Intervention Types in this cluster:")
intervention_counts = cluster_df['intervention_type'].value_counts().head(10)
for intervention, count in intervention_counts.items():
    print(f"  {count:3d} studies ({count/len(cluster_df)*100:4.1f}%): {intervention[:80]}")

print("\n" + "="*50)
print("Sample of actual study titles (randomly selected):")
print("="*50)
sample_titles = cluster_df.sample(min(10, len(cluster_df)), random_state=42)['title'].tolist()
for i, title in enumerate(sample_titles, 1):
    print(f"{i:2d}. {title[:100]}")

print("\n" + "="*50)
print("Most common keywords in TLDRs:")
print("="*50)

# Get word frequency from TLDRs
from collections import Counter
import re

all_text = ' '.join(cluster_df['tldr'].fillna('').tolist()).lower()
words = re.findall(r'\b[a-z]{4,}\b', all_text)  # Words 4+ chars
word_freq = Counter(words)

# Remove common words
common_words = {'study', 'intervention', 'impact', 'results', 'effects', 'group', 'treatment', 'control', 'randomized', 'trial', 'find', 'using', 'assess', 'evaluate'}
filtered_words = {w: c for w, c in word_freq.items() if w not in common_words}

top_words = sorted(filtered_words.items(), key=lambda x: x[1], reverse=True)[:20]
for word, freq in top_words:
    print(f"  {word}: {freq} occurrences")
# Out:
# === Examining Actual Cluster Composition ===
#
# SOLUTION FAMILY 1: 252 studies
#
# Top 10 Intervention Types in this cluster:
#     1 studies ( 0.4%): mentoring; career guidance; professional development; educational intervention
#     1 studies ( 0.4%): goal setting; financial incentives; educational incentives; performance-based re
#     1 studies ( 0.4%): curriculum intervention; socio-emotional skills; grit; deep practice; self-regul
#     1 studies ( 0.4%): growth mindset intervention, educational intervention, psychological interventio
#     1 studies ( 0.4%): pre-service teacher training, classroom transformation, pedagogical methods, pra
#     1 studies ( 0.4%): conditional cash transfers; loss aversion; psychological incentives; behavioral
#     1 studies ( 0.4%): fellowship program; teaching assistants; STEM education; scripted lesson plans;
#     1 studies ( 0.4%): consultancy, coaching, peer coaching, teacher training, skill development, educa
#     1 studies ( 0.4%): diagnostic feedback; capacity-building; standardized testing; professional devel
#     1 studies ( 0.4%): performance management training, web-based dashboard, school improvement plan, w
#
# ==================================================
# Sample of actual study titles (randomly selected):
# ==================================================
#  1. Evaluation of the Teach For America Investing in Innovation Scale-Up
#  2. Teach for science: An impact evaluation of Science Education Initiative’s Fellows Program
#  3. Developing reading fluency in primary school
#  4. Financial Incentives and Student Achievement: Evidence from Randomized Trials
#  5. Effects of providing evidence-based information on teacher's educational technology perceptions
#  6. Stay the Course: Evaluating an Intervention to Promote Community College Persistence and Graduation
#  7. Incentives: Evidence from Uganda
#  8. College Summer School: Educational Benefits and Enrollment Preferences
#  9. Experimental Evidence on Performance Management Training and Tools for Public Schools in Argentina
# 10. Gender Peer Effects in University
#
# ==================================================
# Most common keywords in TLDRs:
# ==================================================
#   students: 196 occurrences
#   with: 117 occurrences
#   school: 88 occurrences
#   student: 80 occurrences
#   significantly: 77 occurrences
#   increased: 70 occurrences
#   schools: 66 occurrences
#   improved: 58 occurrences
#   performance: 56 occurrences
#   scores: 56 occurrences
#   learning: 55 occurrences
#   math: 55 occurrences
#   academic: 54 occurrences
#   high: 51 occurrences
#   that: 51 occurrences
#   program: 48 occurrences
#   significant: 46 occurrences
#   outcomes: 44 occurrences
#   teachers: 43 occurrences
#   this: 43 occurrences

# %%
from together import Together
from google.colab import userdata
import time

# Initialize Together AI client
api_key = userdata.get('TOGETHER_API_KEY')
client = Together(api_key=api_key)

print("=== Comprehensive Solution Family Analysis with Kimi-K2-Instruct ===\n")

solution_families_analysis = {}

# Analyze each cluster with ALL its studies
for cluster_id in range(15):
    cluster_df = df_analysis[df_analysis['solution_family'] == cluster_id]
    cluster_size = len(cluster_df)

    print(f"\n{'='*60}")
    print(f"Analyzing Family {cluster_id} ({cluster_size} studies)...")
    print(f"{'='*60}")

    # Prepare all studies data for this cluster
    studies_list = []
    for idx, row in cluster_df.iterrows():
        study_info = f"• {row['tldr'][:150] if pd.notna(row['tldr']) else 'No summary'} | Intervention: {row['intervention_type'][:50] if pd.notna(row['intervention_type']) else 'N/A'} | Outcome: {row['outcome_extracted'][:50] if pd.notna(row['outcome_extracted']) else 'N/A'}"
        studies_list.append(study_info)

    all_studies_text = "\n".join(studies_list)

    # Create comprehensive prompt
    prompt = f"""You are analyzing a cluster of {cluster_size} development economics RCTs. Read ALL the studies below and identify the common patterns, theories of change, and mechanisms that unite them.

FULL LIST OF STUDIES IN THIS CLUSTER:
{all_studies_text}

Based on analyzing ALL {cluster_size} studies above (not just a sample), provide:

1. SHORT NAME: A catchy 2-4 word name that captures what unites these studies
2. ONE-LINE SUMMARY: One sentence describing the common approach
3. THEORY OF CHANGE: A paragraph explaining the underlying mechanism and logic
4. KEY PATTERNS: What patterns do you see across the studies?
5. DIVERSITY NOTE: If this cluster contains diverse interventions, explain the main sub-types

Format your response exactly like this:
SHORT NAME: [name]
ONE-LINE SUMMARY: [one sentence]
THEORY OF CHANGE: [paragraph]
KEY PATTERNS: [patterns observed]
DIVERSITY NOTE: [sub-types if applicable]"""

    # Get AI response
    try:
        response = client.chat.completions.create(
            model="moonshotai/Kimi-K2-Instruct",
            messages=[{"role": "user", "content": prompt}],
            temperature=0.6,
            max_tokens=500
        )

        analysis = response.choices[0].message.content

        # Parse and display results
        print(f"\n{analysis}")

        # Store results
        solution_families_analysis[cluster_id] = {
            'size': cluster_size,
            'analysis': analysis,
            'studies': cluster_df[['title', 'tldr']].head(5).to_dict('records')  # Keep 5 examples
        }

        # Rate limiting
        time.sleep(1)

    except Exception as e:
        print(f"Error analyzing cluster {cluster_id}: {e}")
        solution_families_analysis[cluster_id] = {
            'size': cluster_size,
            'error': str(e)
        }

print("\n" + "="*60)
print("✓ Complete analysis finished! All clusters analyzed with their FULL content.")
print(f"Total studies analyzed: {len(df_analysis)}")
print(f"Total API cost estimate: ~${len(df_analysis) * 130 * 1.3 / 1_000_000:.2f}")
# Out:
# === Comprehensive Solution Family Analysis with Kimi-K2-Instruct ===
#
#
# ============================================================
# Analyzing Family 0 (128 studies)...
# ============================================================
#
# SHORT NAME: Productivity Boosters
# ONE-LINE SUMMARY: RCTs that test small, low-cost levers—training, incentives, technology, monitoring, or managerial tweaks—to raise worker and firm performance.
# THEORY OF CHANGE: Small frictions (information gaps, weak incentives, poor management, limited skills, psychological stress, or missing technology) keep productivity below potential.  Delivering targeted, bite-sized fixes—whether a mobile app, a two-hour workshop, performance pay, or a feedback text—removes these frictions, raises marginal returns to effort or capital, and triggers self-reinforcing improvements in profits, output, or well-being without large new investments.
# KEY PATTERNS: 1) Training is everywhere (finance, soft skills, leadership, technical, export, AI, stress-management, empathy, cybersecurity). 2) Incentives come in many forms—cash, bonuses, piece-rates, tournament prizes, social recognition, loss-framed clawbacks, peer comparisons, goal-setting. 3) Digital tools (mobile money, apps, AI assistants, online platforms, anonymous messaging) show fast, scalable gains. 4) Managerial practices—monitoring, feedback, attention, autonomy, empowerment—drive sizable effects. 5) Effects are often larger for women, micro-entrepreneurs, or constrained individuals. 6) Short, cheap treatments (a few hours to a few months) can yield 5-30 % productivity jumps. 7) Some gains fade unless reinforced, but many persist months or years.
# DIVERSITY NOTE: Five main sub-types: (1) Worker-level training/incentives (soft skills, health, vision, AI use), (2) SME/entrepreneur support (finance + training, consulting, export training), (3) Managerial practices (monitoring, goal-setting, feedback, empowerment), (4) Technology adoption (mobile apps, AI, remote tools), (5) Institutional/service improvements (private labor-law enforcement, performance scorecards, procurement autonomy).
#
# ============================================================
# Analyzing Family 1 (252 studies)...
# ============================================================
#
# SHORT NAME: Learning Levers Lab
# ONE-LINE SUMMARY: RCTs test how small, low-cost tweaks to inputs—money, information, technology, mentors, peers, or teachers—change learning trajectories.
# THEORY OF CHANGE: Educational production is constrained by weak incentives, imperfect information, and coordination failures among students, parents, teachers, and schools. By altering one input at a time—whether a cash transfer framed as a loss, a growth-mindset text, a diagnostic feedback dashboard, or a same-gender role model—these experiments shift beliefs, effort, or resource allocation just enough to raise achievement, often at scale and for pennies per student. Effects are largest when the tweak (a) directly relaxes a binding constraint (e.g., vision correction, remedial tutoring), (b) leverages behavioral biases (loss aversion, social norms, peer pressure), or (c) is mediated by an influential actor (teacher, parent, mentor) whose own behavior changes first.
# KEY PATTERNS:
# • High-impact, low-cost: most interventions cost <$50 per student and yield 0.1–0.5 SD gains.
# • Heterogeneous returns: benefits rise for girls, low-achievers, or disadvantaged minorities; some treatments backfire for high-achievers or males.
# • Mechanism variety: incentives, information, technology, mentoring, peer effects, teacher coaching, health inputs, and nudges all work, but only when well-aligned with context.
# • Fade-out vs persistence: cognitive gains often fade unless reinforced by complementary inputs; socio-emotional or institutional changes (school management, aspirations) show longer shadows.
# • Scalability cliffs: pilots succeed, but large-scale roll-outs (nationwide SMS campaigns, Danish parent reading programs) lose potency without fidelity or targeting.
# DIVERSITY NOTE: Cluster splits into six sub-types—(1) cash & in-kind transfers (CCTs, eyeglasses, bicycles); (2) information & nudges (feedback, college info, text messages); (3) teacher-focused (coaching, bonuses, training, autonomy); (4) technology-enhanced learning (AI, online tutoring, apps, videos); (5) peer & mentor programs (tutoring, role models, deskmate randomization); (6) governance & management reforms (school-based management, principal training).
#
# ============================================================
# Analyzing Family 2 (122 studies)...
# ============================================================
#
# SHORT NAME: Job Market Lab
# ONE-LINE SUMMARY: 122 RCTs test how small tweaks to information, incentives, or job design move people from job-seeking into better employment.
# THEORY OF CHANGE: Labor markets are thick with frictions—information gaps, search costs, discrimination, and mismatched expectations—that keep workers and good jobs apart. By randomizing light-touch changes (a résumé line, a wage subsidy, a training voucher, a flexible schedule, an online tip, a referral nudge) researchers trace how each friction operates and which levers most cheaply unlock productive matches. The generic pathway is: (1) identify a specific friction, (2) introduce a targeted micro-intervention, (3) observe shifts in application, hiring, retention, or earnings, and (4) scale or discard the lever based on cost-effectiveness.
# KEY PATTERNS:
# - Information dominates: 30+ experiments show that simply providing better labor-market information, feedback, or credible signals (MOOC certificates, startup ratings, local vacancy data) raises employment outcomes.
# - Discrimination is ubiquitous: name, address, age, disability, gender identity, race, college type, and employment gaps all trigger 7-50 % callback penalties, and anonymity or reframing can cut but rarely eliminate them.
# - Flexibility and place matter: work-from-home, hybrid schedules, gig options, and transport subsidies consistently raise take-up, especially for women and youth, by lowering non-wage barriers.
# - Subsidies and training have heterogeneous returns: wage subsidies, apprenticeships, and vocational courses yield 5-25 % earnings gains, but only when aligned with employer demand; generic programs fade quickly.
# - Psychological and social frictions are real: stigma, overconfidence, or lack of networks depress program take-up, while light-touch nudges (motivational emails, network activation, peer referrals) can double participation.
# - Spillovers and general-equilibrium effects appear: migration subsidies raise origin-area wages, gig work crowds out formal jobs, and formalization crackdowns shift workers to other firms rather than destroy employment.
# DIVERSITY NOTE: The cluster splits into five intervention families: (1) information & signaling (résumé audits, expert ratings, MOOC certificates); (2) active labor-market policies (training, wage subsidies, counseling, transitional jobs); (3) job-design & flexibility (remote work, gig
#
# ============================================================
# Analyzing Family 3 (63 studies)...
# ============================================================
#
# SHORT NAME: Digital Influence Lab
# ONE-LINE SUMMARY: RCTs test how digital media, information, and platform design shape beliefs, behavior, and social outcomes.
#
# THEORY OF CHANGE: Digital environments mediate every step from information exposure to real-world action. By varying the content (misinformation vs. facts, partisan vs. neutral), the source (algorithmic, peer, elite, or anonymous), the delivery channel (social media, SMS, radio, TV), and the user’s agency (choice, anonymity, echo-chambers), these experiments trace how cognitive biases, social norms, and identity concerns translate into updated beliefs, altered emotions, and changed decisions—whether to vote, donate, protest, hire, share, or discriminate. The underlying logic is that digital interventions can either reinforce existing preferences (confirmation, polarization, discrimination) or disrupt them (accuracy nudges, cross-cutting exposure, transparency) depending on salient incentives, social visibility, and the cost of deviating from one’s group.
#
# KEY PATTERNS:
# • Information source credibility and messenger identity drive belief change more than message content alone.
# • Social visibility (likes, retweets, peer numbers) amplifies participation but rarely changes underlying preferences.
# • Self-selection and algorithmic curation often deepen partisan or ethnic divides, yet forced cross-cutting exposure can backfire unless carefully framed.
# • Anonymity and reduced social cost increase honest feedback, women’s engagement, and willingness to deviate from group norms.
# • Monetary or social incentives reliably boost observable actions (protest, turnout, donation) but have mixed effects on long-term attitudes.
# • Misinformation persists unless paired with active skills training or platform friction, not mere fact-checking.
# • Digital restriction (ad blocking, platform bans) shifts attention and improves well-being, but substitution effects limit net impact.
# • Discrimination in hiring and housing is measurably shaped by visible social-media cues that trigger stereotypes.
#
# DIVERSITY NOTE: Interventions cluster into four sub-types: (1) content and framing experiments (news slant, rhetoric, misinformation corrections); (2) platform-design tweaks (algorithms, anonymity, echo-chamber manipulation); (3) mobilization tools (SMS reminders, peer endorsements, incentives for voting, protest, donation); and (4) audit/discrimination tests using digital footprints (ethnic names, social profiles).
#
# ============================================================
# Analyzing Family 4 (414 studies)...
# ============================================================
#
# SHORT NAME: Behavioral RCT Universe
# ONE-LINE SUMMARY: A global collection of 414 randomized controlled trials testing how interventions—from nudges to subsidies—change human behavior across health, finance, governance, and markets.
# THEORY OF CHANGE: All studies share a common causal chain: identify a behavioral bottleneck (information gap, market failure, social norm, cognitive bias) → design a low-cost, scalable intervention (information, incentive, framing, institution) → randomize exposure → measure changes in beliefs, preferences, or actions → infer whether the intervention shifts equilibrium behavior. The underlying premise is that small, context-appropriate tweaks can realign individual decisions with socially or privately optimal outcomes by altering incentives, perceptions, or constraints.
# KEY PATTERNS: (1) Information treatments dominate—reminders, labels, disclosures, social norms; (2) Financial incentives (subsidies, matching, fines) are universally tested but often crowd out intrinsic motives; (3) Framing and defaults consistently outperform education alone; (4) Social identity, trust, and fairness drive cooperation and market outcomes; (5) Short-run effects are common, long-run persistence is rare; (6) Digital channels (SMS, apps, online platforms) scale cheaply; (7) Heterogeneous impacts—gender, age, culture, prior beliefs—are the rule, not the exception.
# DIVERSITY NOTE: Four major sub-types coexist: (i) Health/Environment (vaccines, masks, water, energy, recycling); (ii) Financial Inclusion (microcredit, savings, insurance, debt, remittances); (iii) Governance & Public Service Delivery (tax compliance, voting, policing, education, property rights); (iv) Market & Labor (discrimination, pricing, workplace behavior, charitable giving).
#
# ============================================================
# Analyzing Family 5 (42 studies)...
# ============================================================
#
# SHORT NAME: Expectation Engineering
# ONE-LINE SUMMARY: RCTs test how targeted information treatments re-shape public and firm expectations about inflation, interest rates, and macro variables.
# THEORY OF CHANGE: Central banks and researchers assume that expectations are “backward-looking” and sticky; by supplying new, salient, and credible facts (projections, ranges, reforms, or even dissenting views) they can shift priors, update posteriors, and thereby alter real-time spending, saving, pricing, and investment decisions. The mechanism runs from (1) information → (2) belief revision → (3) expectation updating → (4) behavioral response, with heterogeneity driven by prior beliefs, demographics, political identity, and attention.
# KEY PATTERNS:
# - 90 % of studies use randomized surveys or information treatments delivered online or in the field.
# - Treatments vary from central-bank forward guidance, inflation statistics, debt numbers, or even verbal vs. non-verbal Fed communications.
# - Outcomes are overwhelmingly expectations (inflation, interest rates, house prices) and second-round behaviors (spending, borrowing, wage setting).
# - Anchoring effects are stronger when the source is trusted (ECB, Fed) and when the message is simple or numerically precise.
# - Political identity and trust in institutions strongly mediate updating, especially in the U.S.
# - High-inflation contexts (Turkey) show larger behavioral elasticities than low-inflation ones.
# - Firms and households react differently: firms adjust cost and credit expectations, households adjust consumption and job-search intensity.
# DIVERSITY NOTE: Four main sub-types—(i) central-bank communication experiments (forward guidance, dissent, projections), (ii) fiscal-information shocks (debt, deficits, policy uncertainty), (iii) survey-design tweaks (question wording, personalized scales, density formats), and (iv) context-specific shocks (COVID-19, elections, crypto framing).
#
# ============================================================
# Analyzing Family 6 (97 studies)...
# ============================================================
#
# SHORT NAME: Gender Bias Lab
# ONE-LINE SUMMARY: RCTs systematically uncover how stereotypes and structural constraints create gender gaps in markets, politics, and social life, then test corrective policies.
# THEORY OF CHANGE: Gender gaps persist because beliefs (about women's ability, risk tolerance, or social roles) and institutions (hiring rules, loan procedures, political quotas) interact to produce unequal outcomes. RCTs isolate these mechanisms by varying signals (names, avatars, feedback, quotas) or altering rules (salary bans, childcare subsidies, training), then measuring shifts in choices, evaluations, and outcomes. Effective interventions either change beliefs (information, role models, stereotype-busting curricula) or change constraints (childcare, cash-for-work, female police desks), with backlash or spillovers tracked as secondary effects.
# KEY PATTERNS: (1) Discrimination is often statistical or implicit—employers, lenders, peers use gender as a proxy for unobserved traits. (2) Women self-select out of competitive or male-typed domains due to lower confidence or perceived higher standards. (3) Information, role models, and quotas can correct biased beliefs and improve outcomes, but may trigger male backlash when perceived as zero-sum. (4) Mixed-gender teams and exposure interventions reduce bias over time, while single-gender safe spaces build skills and confidence. (5) Context matters: gaps shrink in matrilineal societies, among high-SES youth, or when merit is transparent.
# DIVERSITY NOTE: Interventions cluster into six sub-types—(i) audit/discrimination tests (resumes, Uber rides, Airbnb), (ii) belief-shifting treatments (info campaigns, stereotype training, edutainment), (iii) structural policy pilots (salary history bans, childcare subsidies, cash-for-work), (iv) leadership and quota experiments (female chiefs, political reservation), (v) lab-style games measuring preferences (competition, risk, negotiation), and (vi) technology-enabled tools (safety apps, digital edutainment).
#
# ============================================================
# Analyzing Family 7 (143 studies)...
# ============================================================
#
# SHORT NAME: Info-Impact Nexus
# ONE-LINE SUMMARY: RCTs that test whether giving people better, clearer or simply more information changes what they know, believe, choose or do.
# THEORY OF CHANGE: When information is costly, noisy or biased, actors form distorted beliefs and therefore make “sub-optimal” decisions (health, energy, finance, politics, migration, etc.). Supplying exogenous, low-cost, salient and credible information is expected to update priors, shrink belief errors, shift perceived costs/benefits and ultimately change behavior. The magnitude and direction of the effect depend on how the information is framed, delivered and whether it threatens self-image or existing social norms.
# KEY PATTERNS:
# - Domain ubiquity: same logic applied to energy use, voter behavior, migration choices, HIV testing, meat consumption, retirement claiming, school choice, financial products, etc.
# - Delivery modes: letters, SMS, apps, labels, public reports, documentaries, AI chatbots, door-to-door canvassing, defaults and framing tweaks.
# - Typical effect sizes: small-to-moderate (1-15 pp changes) with high heterogeneity; often zero or backfire when the message clashes with identity, norms or prior beliefs.
# - Heterogeneous impacts: larger among the less informed, poorer, younger, lower-literacy or when stakes and salience are high; smaller or null when default options, social pressure or strong priors dominate.
# - Information avoidance: observed for meat, climate, credit-card debt and flood risk—people actively ignore inconvenient facts.
# - Complementarity: information plus incentives, commitment devices or social norm nudges usually outperforms information alone.
# DIVERSITY NOTE: Three broad sub-types coexist: (1) “corrective” information—supplying missing facts (e.g., HIV risk, flood maps, candidate résumés); (2) “framing & salience” treatments—making existing information clearer or more emotionally resonant (loss vs. gain frames, carbon labels, terminology simplification); (3) “reputation/transparency” interventions—public disclosure that changes third-party or market behavior (mining reports, bus safety scores, councilor report cards).
#
# ============================================================
# Analyzing Family 8 (144 studies)...
# ============================================================
#
# SHORT NAME: Information Shock
# ONE-LINE SUMMARY: Large-scale RCTs test whether giving people new facts, frames or narratives changes their beliefs, preferences and behaviors.
# THEORY OF CHANGE: Most interventions assume that latent preferences are mis-aligned with “objectively” desirable outcomes because people hold biased beliefs about the world (over-estimate immigration, under-estimate inequality, mis-read policy effects). Providing accurate, salient or emotionally resonant information is expected to update priors, reduce uncertainty or social stigma, and thereby shift stated or revealed preferences toward policies or behaviors that are more pro-social, pro-environment, pro-redistribution or pro-institution. The causal chain is: targeted information → belief updating → normative reframing → preference/behavior change → aggregate welfare improvement.
# KEY PATTERNS: (1) Directional heterogeneity: information often polarizes (left/right, high/low income) rather than converges beliefs. (2) Elasticity decays: immediate attitude shifts frequently fade within weeks. (3) Emotions > facts: negative emotional frames (corruption, climate catastrophe) move behavior more than neutral facts. (4) Friction matters: minimal search-cost reductions or excuse removal can amplify effect sizes. (5) Context dependence: effects are larger when stakes are personal (wealth disclosure, COVID risk) and weaker for abstract global issues (foreign aid, climate). (6) Desirability bias: when facts clash with identity or self-interest, motivated reasoning dampens updating.
# DIVERSITY NOTE: Three main sub-clusters—(a) “Corrective statistics” (e.g., racial composition of welfare recipients, top-1 % income share, immigration levels); (b) “Policy framing” (e.g., carbon-tax revenue use, rent-control benefits vs costs); (c) “Institutional transparency” (e.g., MapaInversiones audits, sentencing-disparity disclosure).
#
# ============================================================
# Analyzing Family 9 (85 studies)...
# ============================================================
#
# SHORT NAME: FarmTech Leap
# ONE-LINE SUMMARY: RCTs test how information, finance, insurance and market access can push smallholder farmers to adopt productive technologies and practices.
# THEORY OF CHANGE: Smallholders under-invest in profitable technologies because they face liquidity constraints, uninsured risk, information gaps, and thin or risky markets.  Interventions that relax any one of these constraints—by delivering tailored agronomic advice, subsidised credit or insurance, secure storage, collective marketing, or input vouchers—raise the expected return and reduce the downside risk of new seeds, fertiliser, pest control, irrigation, or post-harvest practices.  Once a critical mass of neighbouring farmers observe higher yields or profits, social learning and network effects accelerate diffusion, making the technology sticky and generating economy-wide productivity gains.
# KEY PATTERNS: (1) Subsidies or free distribution jump-start adoption but can depress later willingness-to-pay; (2) Index insurance repeatedly raises risk-taking and cash-crop shifts, yet take-up hinges on trust, timing and basis-risk; (3) Training plus demonstration plots outperform pure information campaigns, especially when delivered via trusted peers or ICT (SMS, video, WhatsApp); (4) Bundling services—credit + insurance + inputs, or extension + market linkage—produces larger and more sustained impacts than single levers; (5) Social networks, cheap talk, and collective storage/commercialisation amplify treatment effects and spillovers; (6) Liquidity constraints dominate in low-credit settings, while behavioural frictions (cognitive load, procrastination, status-quo bias) matter everywhere; (7) Gendered control of resources and intra-household bargaining moderate the size and distribution of gains.
# DIVERSITY NOTE: Four main sub-types—(i) Technology adoption RCTs (seeds, AWD irrigation, organic/conservation practices, rainwater harvesting); (ii) Financial innovation RCTs (index insurance, micro-credit, cash grants, asset-collateralised loans); (iii) Information & extension RCTs (tailored agronomy, soil testing, weather forecasts, video/ICT training); (iv) Market linkage RCTs (contract farming, collective storage, quality premiums, trader bonuses, DrumNet brokerage).
#
# ============================================================
# Analyzing Family 10 (141 studies)...
# ============================================================
#
# SHORT NAME: Bias & Choice Lab
# ONE-LINE SUMMARY: RCTs dissect how cognitive, social and information frictions shape real-world decisions and design fixes that nudge people toward better outcomes.
# THEORY OF CHANGE: Individuals and organizations deviate from optimal decisions because of systematic biases, limited information, social pressures and institutional rules. By identifying these frictions experimentally—ranging from present-bias and loss-aversion to group dynamics and algorithmic opacity—researchers can redesign choice architecture (defaults, information formats, incentives, training, delegation rules) to reduce the frictions and steer behavior toward higher welfare without removing freedom of choice.
# KEY PATTERNS: (1) Ubiquity of behavioral bias: anchoring, loss-aversion, present-bias, over-optimism, skewness-seeking, luck/choice attribution errors appear across finance, health, labor and policy domains. (2) Framing & information design matter: simplified tables, consequence graphs, narrative storytelling, moral reminders, algorithmic explanations and transparency tools repeatedly improve comprehension and choices. (3) Social context amplifies or dampens bias: group decisions dilute scarcity effects yet magnify ingroup bias; observability boosts prosociality; gender and identity norms distort intra-household and labor-market choices. (4) Delegation & agency introduce new distortions: principals undervalue impact, agents bias advice, and AI can both correct and inject bias depending on transparency and human trust. (5) Light-touch, low-cost interventions—mindfulness nudges, moral prompts, attention capture, scientific decision training—often match or beat high-cost incentives at changing behavior.
# DIVERSITY NOTE: The cluster spans five broad sub-types: (a) individual cognitive-bias tests (risk/time preferences, attribution errors); (b) information-framing and default interventions (retirement products, debt repayment, organ donation); (c) social and identity-based interventions (gender norms, group decision rules, perspective-taking games); (d) technology & algorithmic decision aids (AI credit-scores, algorithmic transparency, facial recognition); (e) organizational and policy decision training (scientific management for SMEs, police de-escalation, legislative responsiveness).
#
# ============================================================
# Analyzing Family 11 (47 studies)...
# ============================================================
#
# SHORT NAME: Tax Compliance Nudges
#
# ONE-LINE SUMMARY: RCTs test low-cost behavioral messages, reminders, information, and enforcement cues to raise tax payment and filing rates.
#
# THEORY OF CHANGE: Most taxpayers want to be compliant but face small psychological frictions—forgetting deadlines, underestimating audit risk, or undervaluing public benefits. Simple, salient, and timely messages that (a) reduce hassle costs (billing codes, auto-pay), (b) increase perceived enforcement (audit threats, fines, third-party verification), or (c) activate social norms and reciprocity (“your neighbors pay”) can shift beliefs and attention just enough to move compliance from the margin of inaction to action. Because the cost of these nudges is pennies per letter/SMS, even modest percentage-point gains in payment or filing rates yield high fiscal returns.
#
# KEY PATTERNS:
# • Delivery channels: letters, SMS, e-mail, WhatsApp, platform prompts, outbound calls.
# • Message families: deterrence (audit/fine risk), social norms, simplification (codes, step-by-step help), moral suasion/public goods, loss aversion, peer comparisons.
# • Target units: individual wage earners, small and informal firms, property owners, EITC claimants, VAT-liable businesses, car-tax payers.
# • Outcomes measured: payment probability, amount paid, filing rates, reported income, debt clearance, audit yields.
# • Typical effect sizes: 5–30 pp increase in compliance; small absolute rupee/USD amounts but large revenue-to-cost ratios.
# • Enforcement × nudge complementarity: reminders work best when backed by credible penalties; pure moral appeals often underperform.
# • Heterogeneity: large effects for debtors, procrastinators, and small firms; muted or zero effects for high-income or already-compliant groups; in some cases information backfires (Togo informal firms reduced participation).
#
# DIVERSITY NOTE: Three broad sub-types coexist—(1) low-touch reminders/letters/SMS, (2) information provision about public spending or tax benefits, and (3) stepped-up enforcement signals (audit probabilities, third-party reporting, performance posting of inspectors).
#
# ============================================================
# Analyzing Family 12 (102 studies)...
# ============================================================
#
# SHORT NAME: Nudge & Nurture
# ONE-LINE SUMMARY: Light-touch behavioral, educational, or psychosocial “nudges” delivered to children, parents, teachers, or communities generate surprisingly large and lasting gains in human-capital and well-being outcomes.
# THEORY OF CHANGE: Small, low-cost inputs—text reminders, mentoring sessions, parenting groups, playful curricula, fortified foods, or simple cash-plus-guidance—shift attention, beliefs, or daily practices of key actors (parents, teachers, children). These micro-changes accumulate into better nutrition, health, socio-emotional skills, and learning, which compound into higher attendance, test scores, and later-life earnings. Because the interventions are cheap and scalable, benefit-cost ratios remain favorable even when effect sizes are modest.
# KEY PATTERNS: (1) Delivery modes are ultra-light: SMS, WhatsApp, radio, short home visits, after-school clubs, or small asset transfers (bicycles, tablets). (2) Target ages cluster around early childhood and adolescence—windows of high plasticity. (3) Parental or caregiver engagement is a repeated mediator; when parents receive information or incentives, child outcomes improve. (4) Social-emotional skills (grit, honesty, self-regulation) are as often measured as cognitive or health gains. (5) Contexts span low- and middle-income countries, with many studies in South Asia and Sub-Saharan Africa. (6) Large-scale public systems (schools, health workers, PDS) are leveraged for distribution. (7) Designs frequently include “light” behavioral levers—labeling, reminders, commitment devices—rather than heavy conditionality.
# DIVERSITY NOTE: Five main sub-types—(a) Parenting & stimulation programs (home visits, virtual coaching), (b) School-based curricula or tutoring (mindset training, remedial teaching, SEL modules), (c) Health & nutrition micro-interventions (deworming, fortified foods, zinc), (d) Cash or asset transfers with light behavioral design (labeled transfers, conditional cash, bicycles), (e) Mentorship & life-skills for youth (girls’ clubs, capoeira, drama workshops).
#
# ============================================================
# Analyzing Family 13 (194 studies)...
# ============================================================
#
# SHORT NAME: Cash-to-Capability Pathways
# ONE-LINE SUMMARY: RCTs test how cash, credit, savings, and in-kind transfers unlock human-capital accumulation and resilience for low-income households.
# THEORY OF CHANGE: Removing liquidity and behavioral constraints (via direct cash, micro-loans, digital wallets, or asset transfers) raises current disposable resources, which—if paired with information, commitment devices, or complementary public goods—are channeled into health, education, business, or risk-coping investments that raise permanent income and subjective well-being. The size, timing, conditionality, delivery channel, and gender of the recipient jointly determine how much of the liquidity gain is saved versus consumed, how far benefits spill over to other household members, and whether gains persist after the transfer stops.
# KEY PATTERNS:
# • Liquidity first: every intervention, whether microcredit, cash CCT, or energy subsidy, ultimately tests how extra cash-on-hand changes behavior.
# • Conditionality & labeling matter: unconditional transfers boost consumption and well-being quickly; conditional ones (health check, school attendance, workfare) tilt spending toward the targeted human-capital domain.
# • Gendered control: transfers targeted to women (Kenya cash+video, Rwanda solar PAYGo, Pakistan Islamic savings) consistently increase child outcomes and women’s empowerment, whereas male-biased gains often show higher private consumption.
# • Digital rails cut costs and leakage: mobile money, biometric smartcards, SMS reminders, and digital CCTs raise take-up, reduce corruption, and create traceable data.
# • Asset-plus-training beats cash alone: graduation packages (livestock plus coaching, sanitation loans plus hygiene training, electrification plus business capital) generate durable income gains, while simple cash or microcredit alone often shows transient or zero impacts.
# • Behavioral frictions dominate: reminders, lockboxes, commitment savings, and social nudges raise savings and repayment even when interest rates or prices barely move.
# • Spillovers & general equilibrium: increased competition among MFIs lowers informal interest rates; in-kind transfers shift local prices; infrastructure (bridges, roads, electricity) crowds in private investment.
# • Diminishing or heterogeneous returns: impacts are largest for the poorest, for first-time recipients, and when markets are thin; benefits fade via hedonic adaptation or debt relapse when follow-up support is absent.
# DIVERSITY NOTE: The cluster spans six broad sub-types: (1
#
# ============================================================
# Analyzing Family 14 (130 studies)...
# ============================================================
#
# SHORT NAME: Behavioral Health Nudges
# ONE-LINE SUMMARY: RCTs test small, low-cost behavioral interventions—information, reminders, incentives, social cues—to shift health-related choices and outcomes.
# THEORY OF CHANGE: Health decisions are shaped more by attention, salience, social norms, and small frictions than by price or knowledge alone. By redesigning how information is framed, when it arrives, who delivers it, and what small rewards or nudges accompany it, programs can change beliefs, reduce hassle costs, and trigger pro-health actions that accumulate into better individual and population-level outcomes without large new infrastructure or clinical services.
# KEY PATTERNS: (1) Modality dominance: SMS, postal letters, radio, WhatsApp, in-person scripts—short, timely, repetitive messaging is everywhere. (2) Incentive size is often tiny (≤US$5–$20) yet still effective for vaccination, screening, adherence. (3) Non-financial motivators—public recognition, social comparison, commitment contracts—work as well as or better than cash for providers and some patients. (4) Peer and social-network effects repeatedly amplify impacts: bring-a-friend vouchers, peer shaming of providers, social-contact deworming spillovers. (5) One-time or short-duration treatments generate lasting effects when they create new habits or social norms (e.g., cooker-retention in Ethiopia, insurance renewal in Ghana). (6) Heterogeneity by gender, bargaining power, trust, and baseline knowledge is reported in nearly every paper, reinforcing that tailoring and targeting matter. (7) Supply-side behavioral levers (provider pay-for-performance, monitoring, non-financial awards) improve service quality without crowding out intrinsically motivated tasks.
# DIVERSITY NOTE: Three large sub-clusters coexist: (a) patient-level nudges—reminders, subsidies, risk messages, commitment devices; (b) provider-level nudges—PBF, social recognition, audit shaming, training; and (c) community/social accountability interventions—scorecards, participatory forums, school or child-led monitoring.
#
# ============================================================
# ✓ Complete analysis finished! All clusters analyzed with their FULL content.
# Total studies analyzed: 2104
# Total API cost estimate: ~$0.36
